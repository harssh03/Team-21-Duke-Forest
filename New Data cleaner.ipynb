# %%
import pandas as pd

# %%
S2_2018 = (pd.read_excel('/Users/harsshgolechha/Desktop/Research/HerpTransData_MASTER.xlsx','2018 Fall'))
S1_2019 = (pd.read_excel('/Users/harsshgolechha/Desktop/Research/HerpTransData_MASTER.xlsx','2019 S1'))
S2_2019 = (pd.read_excel('/Users/harsshgolechha/Desktop/Research/HerpTransData_MASTER.xlsx','2019 S2'))
S1_2020 = (pd.read_excel('/Users/harsshgolechha/Desktop/Research/HerpTransData_MASTER.xlsx','2022 S1'))
S1_2021 = (pd.read_excel('/Users/harsshgolechha/Desktop/Research/HerpTransData_MASTER.xlsx','2021(only NSOE courses data)'))
S1_2022 = (pd.read_excel('/Users/harsshgolechha/Desktop/Research/HerpTransData_MASTER.xlsx','2022 S1'))
S2_2022 = (pd.read_excel('/Users/harsshgolechha/Desktop/Research/HerpTransData_MASTER.xlsx','2022 S2'))
S1_2023 = (pd.read_excel('/Users/harsshgolechha/Desktop/Research/HerpTransData_MASTER.xlsx','2023 S1'))
S2_2023 = (pd.read_excel('/Users/harsshgolechha/Desktop/Research/HerpTransData_MASTER.xlsx','2023 S2'))

S2_2019.head()
# Out:
#             Start Date             End Date Response Type       IP Address  \
# 0  2019-07-15 13:25:48  2019-07-15 13:35:56    IP Address     149.168.27.6
# 1  2019-07-13 17:44:59  2019-07-13 17:54:56    IP Address    107.15.96.222
# 2  2019-07-13 18:00:31  2019-07-13 18:11:06    IP Address    107.15.96.222
# 3  2019-07-14 07:04:10  2019-07-14 07:08:37    IP Address    174.109.101.4
# 4  2019-07-27 10:05:00  2019-07-27 10:14:19    IP Address  162.198.201.245
#
#    Progress  Duration (in seconds)  Finished        Recorded Date  \
# 0       100                    607      True  2019-07-15 13:35:57
# 1       100                    596      True  2019-07-13 17:54:59
# 2       100                    635      True  2019-07-13 18:11:11
# 3       100                    266      True  2019-07-14 07:08:39
# 4       100                    559      True  2019-07-27 10:14:21
#
#          Response ID  Recipient Last Name  ...  \
# 0  R_2YhxoY95M9HosPk                  NaN  ...
# 1  R_2SIENdUBde71Igu                  NaN  ...
# 2  R_QoduTBcQz21I7cJ                  NaN  ...
# 3  R_DwO6zKlJEK47Xnr                  NaN  ...
# 4  R_31TNaFzoQQrisix                  NaN  ...
#
#    Observation of Species\n\nCover ID should be coded "Transect Short Code_Cover ID" (ex. 4_W2, 22_T3, 48-1_W9) - This Occurrence - Photo (y/n).13  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Upload a ZIP file of all of your photos: - Id  \
# 0                                            NaN
# 1                              F_DIGnIuC8lVziuBP
# 2                              F_1i53arrET85qyeI
# 3                                            NaN
# 4                                            NaN
#
#    Upload a ZIP file of all of your photos: - Name  \
# 0                                              NaN
# 1                              2019.07.13_48-1.zip
# 2                              2019.07.13_48-2.zip
# 3                                              NaN
# 4                                              NaN
#
#    Upload a ZIP file of all of your photos: - Size  \
# 0                                              NaN
# 1                                         512616.0
# 2                                        1502035.0
# 3                                              NaN
# 4                                              NaN
#
#    Upload a ZIP file of all of your photos: - Type  \
# 0                                              NaN
# 1                                  application/zip
# 2                                  application/zip
# 3                                              NaN
# 4                                              NaN
#
#   Comments\n\nPlease list any important comments about your findings, your photos, the status of the cover boards on the transect, if you were unable to monitor certain cover boards, or other important information we should know.  \
# 0             Most cover boards were dry underneath.
# 1  This is the same cover we saw American Toad in...
# 2  T4 is splitting along the corrugations. Will n...
# 3                                                NaN
# 4                                                NaN
#
#   Data Sheet Upload\n\nLast Step! Please upload a photo of your completed field data sheet. (PDF or JPG) - Id  \
# 0                                  F_2E5INTjIj0Nn2au
# 1                                  F_2VjOhodgvhLeW6K
# 2                                  F_3MLrPjmZbNMF0tv
# 3                                  F_1LFEfTV6NITZ65c
# 4                                  F_1rkQZyMbwrcM4hV
#
#   Data Sheet Upload\n\nLast Step! Please upload a photo of your completed field data sheet. (PDF or JPG) - Name  \
# 0                                  07-12-2019_22.pdf
# 1                          DataSheet-48-1-190713.pdf
# 2                          DataSheet-48-2-190713.pdf
# 3                                       G4_sheet.jpg
# 4                                       IMG_1113.jpg
#
#   Data Sheet Upload\n\nLast Step! Please upload a photo of your completed field data sheet. (PDF or JPG) - Size  \
# 0                                           393675.0
# 1                                            50301.0
# 2                                            50442.0
# 3                                          1071125.0
# 4                                          2322081.0
#
#   Data Sheet Upload\n\nLast Step! Please upload a photo of your completed field data sheet. (PDF or JPG) - Type
# 0                                    application/pdf
# 1                                    application/pdf
# 2                                    application/pdf
# 3                                         image/jpeg
# 4                                         image/jpeg
#
# [5 rows x 100 columns]

# %%
#is this even needed?
""""S2_2018['Session']='2018_S2'
S1_2019['Session']='2019_S1'
S2_2019['Session']='2019_S2'
S1_2020['Session']='2020_S1'
S1_2021['Session']='2021_S1'
S1_2022['Session']='2022_S1'
S2_2022['Session']='2022_S2'
S1_2023['Session']='2023_S1'
S2_2023['Session']='2023_S2'"""
# Out:
# '"S2_2018[\'Session\']=\'2018_S2\'\nS1_2019[\'Session\']=\'2019_S1\'\nS2_2019[\'Session\']=\'2019_S2\'\nS1_2020[\'Session\']=\'2020_S1\'\nS1_2021[\'Session\']=\'2021_S1\'\nS1_2022[\'Session\']=\'2022_S1\'\nS2_2022[\'Session\']=\'2022_S2\'\nS1_2023[\'Session\']=\'2023_S1\'\nS2_2023[\'Session\']=\'2023_S2\''

# %%
### OBSOLETE DATA REMOVER FUNCTION

# %%
def obsolete_remover(data):
    data = data.drop('Start Date', axis=1)
    data = data.drop('End Date', axis=1)
    data = data.drop('Response Type', axis=1)
    data = data.drop('IP Address', axis=1)
    data = data.drop('Progress', axis=1)
    data = data.drop('Duration (in seconds)', axis=1)
    data = data.drop('Finished', axis=1)
    data = data.drop('Recorded Date', axis=1)
    data = data.drop('Location Latitude', axis=1)
    data = data.drop('Location Longitude', axis=1)
    data = data.drop('User Language', axis=1)
    """data = data.drop('', axis=1)
    data = data.drop('', axis=1)
    data = data.drop('', axis=1)
    data = data.drop('', axis=1)"""
    #data = data.drop(data.columns[[0,1,2,3,4,5,7,9,10,11,12,18]], axis=1)
    data = data.drop('Upload Your Photos - Id', axis=1)
    data = data.drop('Upload Your Photos - Size', axis=1)
    data = data.drop('Upload Your Photos - Type', axis=1)
    data = data.drop('Data Sheet Upload\n\nLast Step! Please upload a scan or photo of your completed field data sheet whether you saw herps or not. (PDF or JPG please).\n\n\n\nIMPORTANT â€“ Please use the following naming convention to name the jpeg or pdf file of your datasheet: YYYY.MM.DD_transectID_Datasheet. For example: "2022.04.27_48-2_Datasheet.pdf" - Id', axis=1)
    data = data.drop('Data Sheet Upload\n\nLast Step! Please upload a scan or photo of your completed field data sheet whether you saw herps or not. (PDF or JPG please).\n\n\n\nIMPORTANT â€“ Please use the following naming convention to name the jpeg or pdf file of your datasheet: YYYY.MM.DD_transectID_Datasheet. For example: "2022.04.27_48-2_Datasheet.pdf" - Size', axis=1)
    data = data.drop('Data Sheet Upload\n\nLast Step! Please upload a scan or photo of your completed field data sheet whether you saw herps or not. (PDF or JPG please).\n\n\n\nIMPORTANT â€“ Please use the following naming convention to name the jpeg or pdf file of your datasheet: YYYY.MM.DD_transectID_Datasheet. For example: "2022.04.27_48-2_Datasheet.pdf" - Type', axis=1)
    data = data.dropna(axis=1,how='all')
    data = data.dropna(axis=0,how='all')
    return data

# %%
S1_2023 = obsolete_remover(S1_2023)

# %%
S1_2023.head()
# Out:
#          Response ID Distribution Channel              Transect ID  \
# 0  R_1IrWBkt8ERCUndV            anonymous     Gate C-2 (DU_GC_C62)
# 1  R_2wTY0cgxaBqr19U            anonymous  Gate C-1  (DU_4_GC_C61)
# 2  R_23VuhDXGolsNvRo            anonymous    Gate 8  (DU_5_G8_C62)
# 3  R_ZLhhpkGHUkVwmU9            anonymous  Gate C-1  (DU_4_GC_C61)
# 4  R_Y50h9t88mvyl7Cp            anonymous     Gate C-2 (DU_GC_C62)
#
#   Survey Date (mm/dd/yyyy) Survey Start Time\n\nRound to the closest hour.  \
# 0               2023-01-27                                        14:00:00
# 1               2023-01-27                                        14:00:00
# 2               2023-02-16                                        17:00:00
# 3               2023-02-18                                        13:00:00
# 4               2023-02-18                                        13:00:00
#
#   Are you a Community Scientist or are you participating in a Duke class?  \
# 0           Participating in a Duke Class (Grunwald)
# 1           Participating in a Duke Class (Grunwald)
# 2                                  Duke Forest Staff
# 3                                  Duke Forest Staff
# 4                                  Duke Forest Staff
#
#   What team was scheduled for this transect?          Email Address  \
# 0                                        NaN  ron.grunwald@duke.edu
# 1                                        NaN  ron.grunwald@duke.edu
# 2                                        NaN                    NaN
# 3                                        NaN                    NaN
# 4                                        NaN                    NaN
#
#   Observer Names\n\nPlease include all Observers' full names, including First and Last names. - Recorder (you)  \
# 0                                       Ron Grunwald
# 1          Maggie Heraty (on behalf of Ron Grunwald)
# 2                                      Maggie Heraty
# 3                                      Maggie Heraty
# 4                                      Maggie Heraty
#
#   Observer Names\n\nPlease include all Observers' full names, including First and Last names. - Other Observer(s)  \
# 0            Angela Addae, Nia Williams, Emi Hegarty
# 1  Bio348LS class (aggregate) - Angela Addae, Dan...
# 2  2023 Herp Program Make-up Training: Susan Prat...
# 3  Field Trip for the Duke Health and Environment...
# 4  Field Trip for the Duke Health and Environment...
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Observation of Species\nCover ID should be coded "Short Transect ID_Cover ID" (ex. 4_W2, 22_T3, 48-1_W9) - This Occurrence - Total.11  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Observation of Species\nCover ID should be coded "Short Transect ID_Cover ID" (ex. 4_W2, 22_T3, 48-1_W9) - This Occurrence - Photo (y/n).11  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Species/Occurrence 15  \
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
#   Observation of Species\nCover ID should be coded "Short Transect ID_Cover ID" (ex. 4_W2, 22_T3, 48-1_W9) - This Occurrence - Cover ID.12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Observation of Species\nCover ID should be coded "Short Transect ID_Cover ID" (ex. 4_W2, 22_T3, 48-1_W9) - This Occurrence - Total.12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Observation of Species\nCover ID should be coded "Short Transect ID_Cover ID" (ex. 4_W2, 22_T3, 48-1_W9) - This Occurrence - Photo (y/n).12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#     Upload Your Photos - Name  \
# 0  2023.01.27_C-2_Photos.docx
# 1         2023.01.27_C-1.docx
# 2    2023.02.16_8_Photos.docx
# 3  2023.02.18_C-1_Photos.docx
# 4  2023.02.18_C-2_Photos.docx
#
#   Data Sheet Upload\n\nLast Step! Please upload a scan or photo of your completed field data sheet whether you saw herps or not. (PDF or JPG please).\n\n\n\nIMPORTANT â€“ Please use the following naming convention to name the jpeg or pdf file of your datasheet: YYYY.MM.DD_transectID_Datasheet. For example: "2022.04.27_48-2_Datasheet.pdf" - Name  \
# 0                      2023.01.27_C-2_Data Sheet.pdf
# 1                     2023.01.27_C-1_Data sheet .pdf
# 2                         2023.02.16_8_Datasheet.pdf
# 3                       2023.02.18_C-1_Datasheet.JPG
# 4                       2023.02.18_C-2_Datasheet.JPG
#
#   Comments/Issues\n\nPlease list any important comments about your data (observations, photos, or other important information we should know). \n\n\n\nIf you are a Community Scientist volunteer and have "Damage to report" or other transect conditions to report, please use the Transect Maintenance tab in the @Data channel in MS Teams. If you are a student/staff/researcher, please put it here.  \
# 0                                                NaN
# 1  ALL salamanders observed during this transect ...
# 2  At coverboard 8_T2, 20% of the ground surface ...
# 3  This data was collected by undergraduate mento...
# 4  This data was collected by undergraduate mento...
#
#                              Administrative Comments
# 0  Photos were not provided for every Red-Backed ...
# 1                                                NaN
# 2                      Field mouse observed at 8_T1.
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 83 columns]

# %%
species_cols = [col for col in S1_2023.columns if 'Species/Occurrence ' in col]
sublist=species_cols
cover_id=S1_2023.iloc[:,S1_2023.columns.get_indexer(sublist)+1]
occurrence_total=S1_2023.iloc[:,S1_2023.columns.get_indexer(sublist)+2]
melt_species=pd.melt(S1_2023, id_vars=['Response ID','Survey Date (mm/dd/yyyy)','Survey Start Time\n\nRound to the closest hour.','Are you a Community Scientist or are you participating in a Duke class?','Transect ID','Temperature, in degrees Fahrenheit.\n\n\n\n**Simply write the number, i.e. 55 or 78. No need to include "Â°F" or "degrees".', 'Sky Condition / Precipitation Status'], value_vars= species_cols, var_name='Species_Occurrence',value_name='Species').sort_values('Response ID')
# make separate occurrence column
melt_species[['Species_OccurrenceCol', 'OccurrenceNum']] = melt_species['Species_Occurrence'].str.split(' ', expand=True)

# %%
species_cols = [col for col in S1_2023.columns if 'Species/Occurrence ' in col]
coverid_cols = [col for col in S1_2023.columns if 'Occurrence - Cover ID' in col]
total_cols = [col for col in S1_2023.columns if 'Occurrence - Total' in col]
melt_coverids=pd.melt(S1_2023, id_vars=['Response ID'], value_vars= coverid_cols,\
    var_name='Cover_ID', value_name='Transect_Cover').sort_values('Response ID')

# %%
species_cols = [col for col in S1_2023.columns if 'Species/Occurrence ' in col]
coverid_cols = [col for col in S1_2023.columns if 'Occurrence - Cover ID' in col]
total_cols = [col for col in S1_2023.columns if 'Occurrence - Total' in col]
melt_totals=pd.melt(S1_2023, id_vars=['Response ID'], value_vars= total_cols,var_name='Totals', value_name='Species_Totals').sort_values('Response ID')

# %%
usable_S1_2023 = pd.concat([melt_species,melt_coverids,melt_totals], axis="columns").drop_duplicates()
usable_S1_2023=usable_S1_2023[['Response ID','Survey Date (mm/dd/yyyy)','Survey Start Time\n\nRound to the closest hour.','Are you a Community Scientist or are you participating in a Duke class?','Transect ID','Temperature, in degrees Fahrenheit.\n\n\n\n**Simply write the number, i.e. 55 or 78. No need to include "Â°F" or "degrees".', 'Sky Condition / Precipitation Status','Species','OccurrenceNum','Transect_Cover','Species_Totals']]

# %%
usable_S1_2023.head()
# Out:
#             Response ID        Response ID        Response ID  \
# 1194  R_10OaVqcM2ppFLsV  R_10OaVqcM2ppFLsV  R_10OaVqcM2ppFLsV
# 535   R_10OaVqcM2ppFLsV  R_10OaVqcM2ppFLsV  R_10OaVqcM2ppFLsV
# 1855  R_10OaVqcM2ppFLsV  R_10OaVqcM2ppFLsV  R_10OaVqcM2ppFLsV
# 1854  R_10OaVqcM2ppFLsV  R_10OaVqcM2ppFLsV  R_10OaVqcM2ppFLsV
# 1723  R_10OaVqcM2ppFLsV  R_10OaVqcM2ppFLsV  R_10OaVqcM2ppFLsV
#
#      Survey Date (mm/dd/yyyy) Survey Start Time\n\nRound to the closest hour.  \
# 1194               2023-02-19                                        10:00:00
# 535                2023-02-19                                        10:00:00
# 1855               2023-02-19                                        10:00:00
# 1854               2023-02-19                                        10:00:00
# 1723               2023-02-19                                        10:00:00
#
#      Are you a Community Scientist or are you participating in a Duke class?  \
# 1194                                  Duke Forest Staff
# 535                                   Duke Forest Staff
# 1855                                  Duke Forest Staff
# 1854                                  Duke Forest Staff
# 1723                                  Duke Forest Staff
#
#                   Transect ID  \
# 1194  Gate C-1  (DU_4_GC_C61)
# 535   Gate C-1  (DU_4_GC_C61)
# 1855  Gate C-1  (DU_4_GC_C61)
# 1854  Gate C-1  (DU_4_GC_C61)
# 1723  Gate C-1  (DU_4_GC_C61)
#
#       Temperature, in degrees Fahrenheit.\n\n\n\n**Simply write the number, i.e. 55 or 78. No need to include "Â°F" or "degrees".  \
# 1194                                               47.0
# 535                                                47.0
# 1855                                               47.0
# 1854                                               47.0
# 1723                                               47.0
#
#      Sky Condition / Precipitation Status  \
# 1194                                Sunny
# 535                                 Sunny
# 1855                                Sunny
# 1854                                Sunny
# 1723                                Sunny
#
#                                                 Species OccurrenceNum  \
# 1194  Red-backed Salamander (Plethodon cinereus) - R...            10
# 535                                                 NaN             5
# 1855                                                NaN            15
# 1854                                         Black Ants            15
# 1723                                                NaN            14
#
#      Transect_Cover Species_Totals
# 1194         C-1_W6              2
# 535             NaN            NaN
# 1855            NaN            NaN
# 1854         C-1_T2            0.3
# 1723            NaN            NaN
